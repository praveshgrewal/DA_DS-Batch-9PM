# %%
class Course:
    def __init__(self,subject,duration,collage): # constuctor
        self.subject = subject
        self.duration = duration
        self.collage = collage

# object
my_course = Course('python',2,'IITG')
print(my_course.collage)
print(my_course.subject)
print(my_course.duration)

suhani_course = Course("DS","6month","Entry globe")
print(suhani_course.subject)
print(suhani_course.duration)
print(suhani_course.collage)
# Out:
# IITG
# python
# 2
# DS
# 6month
# Entry globe

# %%
print(type(3.6))
# Out:
# <class 'float'>

# %%
class Course:
    def __init__(self,subject,duration,collage): # constuctor
        self.subject = subject
        self.duration = duration
        self.collage = collage

    def full_details(self):
        return f"{self.subject}:{self.duration},:{self.collage}"

suhani_course = Course("DS","6month","Entry globe")
print(suhani_course.full_details())
# Out:
# DS:6month,:Entry globe

# %%
class Mathes:
    def __init__(self,num,num2):
        self.num = num
        self.num2 = num2

    def add(self):
        return self.num + self.num2

    def sub(self):
        return self.num-self.num2


a= Mathes(23,45)
print(a.add())
print(a.sub())
# Out:
# 68
# -22
