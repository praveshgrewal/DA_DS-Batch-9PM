# %% [markdown]
# ### we have to if user is greater then 18 we will give pan card other wise we will not give pancard

# %%
age = int(input('Enter Your Age: '))
if age > 18:
    print("You are eligible for Pancard")
else:
    print("better luck next time")
# Out:
# You are eligible for Pancard

# %%
marks = 50
if marks > 50:
    result ="pass"
else:
    result = "fail"
print(result)
# Out:
# fail

# %%
# even / odd
num = int(input('Enter Your Number: '))
if num % 2 == 0:
    print(f"{num} is a Even number ")
else:
    print(f"{num} is a odd number")
# Out:
# 12 is a Even number

# %%
11%2==0
# Out:
# False

# %%
name = "suhani"
age = 18
# my name is suhani and i am 18 years old
print("my name is",name,"i am",age,"years old")
# Out:
# my name is suhani i am 18 years old

# %%
# f-string
print(f"my name is {name} and i am {age} years old")
# Out:
# my name is suhani and i am 18 years old

# %%
age = 2
mapper = "adult" if age > 18 else "child"
print(mapper)
# Out:
# child

# %% [markdown]
# ### if,elif ,else
# * marks = 90+ -- >a
# * 70--90 -- >b
# * 40-70--> c
# * rest of the all are fail

# %%
marks = 23
if marks > 90:
    result = "A"
elif marks > 70:
    result = "B"
elif marks > 40:
    result = "C"
else:
    result = "D"

print(f"Congratulation! you got Grade {result}")
# Out:
# Congratulation! you got Grade D

# %%
name
# Out:
# 'suhani'

# %%
len(name)
# Out:
# 6

# %% [markdown]
# ### nested if else

# %%
# age. >18 , marks > 50
age = 19
marks = 67
if age>18:
    if marks > 50:
        print("Pass")
    else:
        print("fail")
else:
    print("Abhi tu bacha hai")
# Out:
# Pass

# %%
# salary > 50000,credit_score = 700+ we will give loan other wise not
salary = 67000
credit_score = 890
if salary  >50000:
    if credit_score > 700:
        print("eligible for loan")
    else:
        print("not eligible")
else:
    print("salary is low")
# Out:
# eligible for loan

# %%
salary = 67000
credit_score = 890

if salary>50000 and credit_score>700:
    print("eligible for loan")
else:
    print("better luck next time")
# Out:
# eligible for loan

# %% [markdown]
# # Python If-Else Practical Questions
#
# ### Q1. Even or Odd Number
# Write a program that takes a number as input and checks whether it is even or odd.
#
# ---
#
# ### Q2. Voting Eligibility Checker
# Write a program that takes a person's age as input and determines whether they are eligible to vote (18 years or older).
#
# ---
#
# ### Q3. Pass or Fail System
# Write a program that takes a student's marks as input and displays:
# - "Pass" if marks are 40 or above
# - "Fail" otherwise
#
# ---
#
# ### Q4. Positive, Negative, or Zero
# Write a program that accepts a number and determines whether it is:
# - Positive
# - Negative
# - Zero
#
# ---
#
# ### Q5. Largest of Two Numbers
# Write a program that takes two numbers as input and displays the larger number.
#
# ---
#
# ### Q6. ATM Withdrawal Validation
# Write a program that asks the user for:
# - Account Balance
# - Withdrawal Amount
#
# Check whether the withdrawal is possible.
# - If balance is sufficient, display "Withdrawal Successful"
# - Otherwise, display "Insufficient Balance"
#
# ---
#
# ### Q7. Login Authentication System
# Create a simple login system.
#
# Use:
# - Username = `admin`
# - Password = `python123`
#
# Ask the user to enter username and password.
#
# Display:
# - "Login Successful" if both are correct
# - "Invalid Credentials" otherwise
#
# ---
#
# ### Q8. Electricity Bill Discount Calculator
# Write a program that accepts an electricity bill amount.
#
# Conditions:
# - If bill amount is greater than ₹5000, apply a 10% discount.
# - Otherwise, no discount.
#
# Display the final bill amount.
#
# ---
#
# ### Q9. Find the Greatest of Three Numbers
# Write a program that accepts three numbers from the user and displays the greatest number among them.
#
# ---
#
# ### Q10. E-Commerce Coupon Checker
# Write a program that asks the user for the cart value.
#
# Conditions:
# - If cart value is ₹2000 or more, apply a ₹200 discount.
# - Otherwise, no discount.
#
# Display:
# - Original Amount
# - Discount Amount
# - Final Amount Payable
