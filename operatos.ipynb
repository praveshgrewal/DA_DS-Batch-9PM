# %% [markdown]
# ## Arithmetic operators
# * +	Addition	x + y
# * -	Subtraction	x - y
# * *	Multiplication	x * y
# * /	Division	x / y
# * %	Modulus	x % y
# * **	Exponentiation	x ** y
# * //	Floor division	x // y

# %%
num = 12
num2 = 5
print(num + num2) # addition
print(num - num2) # subtraction
print(num * num2) # multiplication
print(num / num2) # division --> gives float value
print(num // num2) # floor division --> gives integer value
print(num % num2) # modulus --> gives remainder value
print(num ** num2) # exponentiation --> gives power value
# Out:
# 17
# 7
# 60
# 2.4
# 2
# 2
# 248832

# %%
12+4
# Out:
# 16

# %% [markdown]
# ## assignment operator

# %%
name = "suhani" # = is an assignment operator
print(name)
# Out:
# suhani

# %%
num4 = 10
num4 = num4+2
print(num4)
# Out:
# 12

# %%
num4 += 2 # num4 = num4 + 2
print(num4)
# Out:
# 14

# %%
num5 = 12
num5 += 3 # num5 = num5 + 3
print(num5)
# Out:
# 15

# %%
num5 -= 3
print(num5)
# Out:
# 12

# %% [markdown]
# ## comparison operators(realtional operators)

# %%
num9 = 120
num10 = 12
print(num9 == num10) # equal to operator
print(num9 != num10) # not equal to operator
print(num9 > num10) # greater than operator
print(num9 >= num10) # greater than or equal to operator
print(num9 < num10) # less than operator
print(num9 <= num10) # less than or equal to operator
# Out:
# False
# True
# True
# True
# False
# False

# %% [markdown]
# ## membership
# * in
# * not in

# %%
name = "suhani"
print("I" in name)
print("A" not in name)
# Out:
# False
# True

# %% [markdown]
# ## logical opertors
# * and
# * or
# * not

# %%
print(True and False) # True
print(10>4 and 10 > 6 )
print(True or False) # True
print(10>4 or 10 > 6 )
print(not True) # False
# Out:
# False
# True
# True
# True
# False

# %% [markdown]
# ## identity operators
# * is
# * is not

# %%
x = 10
y= 10
z = 67
print(id(x))
print(id(y))
print(id(z))
# Out:
# 4378043448
# 4378043448
# 4378045272

# %%
print(x is y)
print(x is z)
# Out:
# True
# False
