# %%
print("my self pravesh grewal. WELCOME IN ENTRYGLOBE")
# Out:
# pravesh grewal

# %%
suhani = "my name is suhani rohilla"
print(suhani)
# Out:
# my name is suhani rohilla

# %% [markdown]
# #### name is a variable here and anupama is a value

# %% [markdown]
# #### id ---> to show memory location

# %%
name = "anupama" 
print(name)
print(id(name))
# Out:
# anupama
# 4503271968

# %%
name2 = "suhani"
print(name2)
print(id(name2))
# Out:
# suhani
# 4474350176

# %%
name3 = "suhani"
print(name3)
print(id(name3))
# Out:
# suhani
# 4474350176

# %%
# hii this is changes

# %%
num = 10
print(num)
print(id(num))
# Out:
# 10
# 4346979384

# %%
num2 = 10
print(num2)
print(id(num2))
# Out:
# 10
# 4346979384

# %% [markdown]
# ### if we have same values memory location will be same

# %% [markdown]
# ## we have some rules and ragulation for python variables

# %%
# comments ---> notes 
# ctrl + /  ----> to comment and uncomment the code

# %%
# hii this is suhani

# %% [markdown]
# #### variable can't start from number

# %%
10 = "hii"
print(10)
# Out:
#   Cell In[8], line 1
#     10 = "hii"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# #### variables can't contain special char or space (_)

# %%
name-student = "suhani"
print(name@student)
# Out:
#   Cell In[12], line 1
#     name-student = "suhani"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# #### variable can't be a keyword(reserve words )

# %%
if = "data science"
print(if)
# Out:
#   Cell In[15], line 1
#     if = "data science"
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# #### python is a case sensitive programming lang
# * capital case and small case will treat diff

# %%
School = "entryglobe" # upper case variable
print(school) # lower case variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 School = "entryglobe"
# ----> 2 print(school)
#
# NameError: name 'school' is not defined

# %% [markdown]
# #### best way to create a variable
# * use _
# * can contain number but firstly char
# * python support snake case (_)

# %%
name_student = "suhani"
print(name_student)
# Out:
# suhani

# %%
name4 = "suhani"
print(name4)
# Out:
# suhani

# %%
# camle case
myNameIsSuhani = "suhani"
print(myNameIsSuhani)
# Out:
# suhani

# %%
# pep-8 ---> python enhancement proposal

# %%
a,b,c = 10,20,30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
x=y=z=10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
x=y=z = 10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %% [markdown]
# #### ctrl+enter
# #### shift+enter
