# %% [markdown]
# ## dict ---> {'key':'value'}
# * mutable
# * keys --> immutable
# * values ---> mutable
# * keys will be unique
# * value can be duplicate

# %%
data= {
    'Name':'Suhani',
    'Age':18,
    'School':'Nava Hind',
    'Course':'DA_DS'

}
print(data)
print(type(data))
# Out:
# {'Name': 'Suhani', 'Age': 18, 'School': 'Nava Hind', 'Course': 'DA_DS'}
# <class 'dict'>

# %%
data['Name'] = "Suhani Rohilla"
data
# Out:
# {'Name': 'Suhani Rohilla', 'Age': 18, 'School': 'Nava Hind', 'Course': 'DA_DS'}

# %% [markdown]
# ### if there is any available key it will update otherwise it will add

# %%
data['address'] = "New Delhi"
data
# Out:
# {'Name': 'Suhani Rohilla',
#  'Age': 18,
#  'School': 'Nava Hind',
#  'Course': 'DA_DS',
#  'address': 'New Delhi'}

# %%
student_data = {
    'Names':['suhani','anu','peehu','suniti'],
    'Age':[18,24,26,17],
    'Marks':[23,27,89,33]
}
print(student_data)
# Out:
# {'Names': ['suhani', 'anu', 'peehu', 'suniti'], 'Age': [18, 24, 26, 17], 'Marks': [23, 27, 89, 33]}

# %%
student_data['Marks'][1]
# Out:
# 27

# %%
data
# Out:
# {'Name': 'Suhani Rohilla',
#  'Age': 18,
#  'School': 'Nava Hind',
#  'Course': 'DA_DS',
#  'address': 'New Delhi'}

# %%
data.keys()
# Out:
# dict_keys(['Name', 'Age', 'School', 'Course', 'address'])

# %%
data.values()
# Out:
# dict_values(['Suhani Rohilla', 18, 'Nava Hind', 'DA_DS', 'New Delhi'])

# %%
data.items()
# Out:
# dict_items([('Name', 'Suhani Rohilla'), ('Age', 18), ('School', 'Nava Hind'), ('Course', 'DA_DS'), ('address', 'New Delhi')])

# %%
print(dir(dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
data
# Out:
# {'Name': 'Suhani Rohilla',
#  'Age': 18,
#  'School': 'Nava Hind',
#  'Course': 'DA_DS',
#  'address': 'New Delhi'}

# %%
data.pop('address')
# Out:
# 'New Delhi'

# %%
data
# Out:
# {'Name': 'Suhani Rohilla', 'Age': 18, 'School': 'Nava Hind', 'Course': 'DA_DS'}

# %%
data.popitem()
# Out:
# ('Course', 'DA_DS')

# %%
data
# Out:
# {'Name': 'Suhani Rohilla', 'Age': 18, 'School': 'Nava Hind'}

# %%
data.get('Name','Not found')
# Out:
# 'Suhani Rohilla'

# %%
data.get('Names','Not found')
# Out:
# 'Not found'

# %%
student_data
# Out:
# {'Names': ['suhani', 'anu', 'peehu', 'suniti'],
#  'Age': [18, 24, 26, 17],
#  'Marks': [23, 27, 89, 33]}

# %%
data.update(student_data)
data
# Out:
# {'Name': 'Suhani Rohilla',
#  'Age': [18, 24, 26, 17],
#  'School': 'Nava Hind',
#  'Names': ['suhani', 'anu', 'peehu', 'suniti'],
#  'Marks': [23, 27, 89, 33]}
